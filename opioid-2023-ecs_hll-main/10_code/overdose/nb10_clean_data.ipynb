# %%
from pathlib import Path
import pandas as pd
import numpy as np
import os

pd.set_option("mode.copy_on_write", True)

repo_root = Path("../..")
# source files
src_folder = repo_root / "00_source_data" / "mortality_data"

# output file
out_file = repo_root / "20_intermediate_file" / "overdose_03-15.tsv"

# %%
df_list = [pd.read_csv(p, sep="\t") for p in src_folder.glob("*")]
df = pd.concat(df_list)
df
# Out:
#                                                   Notes              County  \
# 0                                                   NaN  Autauga County, AL
# 1                                                   NaN  Baldwin County, AL
# 2                                                   NaN  Baldwin County, AL
# 3                                                   NaN  Barbour County, AL
# 4                                                   NaN     Bibb County, AL
# ...                                                 ...                 ...
# 4604  Suggested Citation: Centers for Disease Contro...                 NaN
# 4605  1999-2017 on CDC WONDER Online Database, relea...                 NaN
# 4606  compiled from data provided by the 57 vital st...                 NaN
# 4607  at http://wonder.cdc.gov/ucd-icd10.html on Oct...                 NaN
# 4608                                                ---                 NaN
#
#       County Code    Year  Year Code  \
# 0          1001.0  2009.0     2009.0
# 1          1003.0  2009.0     2009.0
# 2          1003.0  2009.0     2009.0
# 3          1005.0  2009.0     2009.0
# 4          1007.0  2009.0     2009.0
# ...           ...     ...        ...
# 4604          NaN     NaN        NaN
# 4605          NaN     NaN        NaN
# 4606          NaN     NaN        NaN
# 4607          NaN     NaN        NaN
# 4608          NaN     NaN        NaN
#
#                              Drug/Alcohol Induced Cause  \
# 0             All other non-drug and non-alcohol causes
# 1     Drug poisonings (overdose) Unintentional (X40-...
# 2             All other non-drug and non-alcohol causes
# 3             All other non-drug and non-alcohol causes
# 4             All other non-drug and non-alcohol causes
# ...                                                 ...
# 4604                                                NaN
# 4605                                                NaN
# 4606                                                NaN
# 4607                                                NaN
# 4608                                                NaN
#
#      Drug/Alcohol Induced Cause Code  Deaths
# 0                                 O9   408.0
# 1                                 D1    29.0
# 2                                 O9  1669.0
# 3                                 O9   299.0
# 4                                 O9   207.0
# ...                              ...     ...
# 4604                             NaN     NaN
# 4605                             NaN     NaN
# 4606                             NaN     NaN
# 4607                             NaN     NaN
# 4608                             NaN     NaN
#
# [57436 rows x 8 columns]

# %%
causes = df[
    ["Drug/Alcohol Induced Cause", "Drug/Alcohol Induced Cause Code"]
].value_counts()
causes
# Out:
# Drug/Alcohol Induced Cause                          Drug/Alcohol Induced Cause Code
# All other non-drug and non-alcohol causes           O9                                 40337
# Drug poisonings (overdose) Unintentional (X40-X44)  D1                                  7573
# All other alcohol-induced causes                    A9                                  6123
# Drug poisonings (overdose) Suicide (X60-X64)        D2                                  1465
# Drug poisonings (overdose) Undetermined (Y10-Y14)   D4                                   761
# All other drug-induced causes                       D9                                   628
# Alcohol poisonings (overdose) (X45, X65, Y15)       A1                                   349
# Drug poisonings (overdose) Homicide (X85)           D3                                     5
# Name: count, dtype: int64

# %%
overdoses = ["D1", "D2", "D3", "D4"]

# %%
df.County.nunique(), df[
    df["Drug/Alcohol Induced Cause Code"].isin(overdoses)
].County.nunique()
# Out:
# (3132, 1047)

# %%
df[df["Deaths"].isna()]
# Out:
#                                                   Notes County  County Code  \
# 4364                                                ---    NaN          NaN
# 4365      Dataset: Underlying Cause of Death, 1999-2017    NaN          NaN
# 4366                                  Query Parameters:    NaN          NaN
# 4367  Group By: County; Year; Drug/Alcohol Induced C...    NaN          NaN
# 4368                              Show Totals: Disabled    NaN          NaN
# ...                                                 ...    ...          ...
# 4604  Suggested Citation: Centers for Disease Contro...    NaN          NaN
# 4605  1999-2017 on CDC WONDER Online Database, relea...    NaN          NaN
# 4606  compiled from data provided by the 57 vital st...    NaN          NaN
# 4607  at http://wonder.cdc.gov/ucd-icd10.html on Oct...    NaN          NaN
# 4608                                                ---    NaN          NaN
#
#       Year  Year Code Drug/Alcohol Induced Cause  \
# 4364   NaN        NaN                        NaN
# 4365   NaN        NaN                        NaN
# 4366   NaN        NaN                        NaN
# 4367   NaN        NaN                        NaN
# 4368   NaN        NaN                        NaN
# ...    ...        ...                        ...
# 4604   NaN        NaN                        NaN
# 4605   NaN        NaN                        NaN
# 4606   NaN        NaN                        NaN
# 4607   NaN        NaN                        NaN
# 4608   NaN        NaN                        NaN
#
#      Drug/Alcohol Induced Cause Code Deaths
# 4364                             NaN    NaN
# 4365                             NaN    NaN
# 4366                             NaN    NaN
# 4367                             NaN    NaN
# 4368                             NaN    NaN
# ...                              ...    ...
# 4604                             NaN    NaN
# 4605                             NaN    NaN
# 4606                             NaN    NaN
# 4607                             NaN    NaN
# 4608                             NaN    NaN
#
# [195 rows x 8 columns]

# %%
# check that all these entries are notes
assert (df["Notes"].notna() == df["Deaths"].isna()).all()

# %%
clean_df = df[df["Notes"].isna()]
clean_df
# Out:
#      Notes                 County  County Code    Year  Year Code  \
# 0      NaN     Autauga County, AL       1001.0  2009.0     2009.0
# 1      NaN     Baldwin County, AL       1003.0  2009.0     2009.0
# 2      NaN     Baldwin County, AL       1003.0  2009.0     2009.0
# 3      NaN     Barbour County, AL       1005.0  2009.0     2009.0
# 4      NaN        Bibb County, AL       1007.0  2009.0     2009.0
# ...    ...                    ...          ...     ...        ...
# 4589   NaN  Sweetwater County, WY      56037.0  2013.0     2013.0
# 4590   NaN       Teton County, WY      56039.0  2013.0     2013.0
# 4591   NaN       Uinta County, WY      56041.0  2013.0     2013.0
# 4592   NaN    Washakie County, WY      56043.0  2013.0     2013.0
# 4593   NaN      Weston County, WY      56045.0  2013.0     2013.0
#
#                              Drug/Alcohol Induced Cause  \
# 0             All other non-drug and non-alcohol causes
# 1     Drug poisonings (overdose) Unintentional (X40-...
# 2             All other non-drug and non-alcohol causes
# 3             All other non-drug and non-alcohol causes
# 4             All other non-drug and non-alcohol causes
# ...                                                 ...
# 4589          All other non-drug and non-alcohol causes
# 4590          All other non-drug and non-alcohol causes
# 4591          All other non-drug and non-alcohol causes
# 4592          All other non-drug and non-alcohol causes
# 4593          All other non-drug and non-alcohol causes
#
#      Drug/Alcohol Induced Cause Code  Deaths
# 0                                 O9   408.0
# 1                                 D1    29.0
# 2                                 O9  1669.0
# 3                                 O9   299.0
# 4                                 O9   207.0
# ...                              ...     ...
# 4589                              O9   238.0
# 4590                              O9    83.0
# 4591                              O9   130.0
# 4592                              O9    72.0
# 4593                              O9    66.0
#
# [57241 rows x 8 columns]

# %%
clean_df.drop(
    inplace=True, columns=["Notes", "Year Code", "Drug/Alcohol Induced Cause"]
)
clean_df
# Out:
#                      County  County Code    Year  \
# 0        Autauga County, AL       1001.0  2009.0
# 1        Baldwin County, AL       1003.0  2009.0
# 2        Baldwin County, AL       1003.0  2009.0
# 3        Barbour County, AL       1005.0  2009.0
# 4           Bibb County, AL       1007.0  2009.0
# ...                     ...          ...     ...
# 4589  Sweetwater County, WY      56037.0  2013.0
# 4590       Teton County, WY      56039.0  2013.0
# 4591       Uinta County, WY      56041.0  2013.0
# 4592    Washakie County, WY      56043.0  2013.0
# 4593      Weston County, WY      56045.0  2013.0
#
#      Drug/Alcohol Induced Cause Code  Deaths
# 0                                 O9   408.0
# 1                                 D1    29.0
# 2                                 O9  1669.0
# 3                                 O9   299.0
# 4                                 O9   207.0
# ...                              ...     ...
# 4589                              O9   238.0
# 4590                              O9    83.0
# 4591                              O9   130.0
# 4592                              O9    72.0
# 4593                              O9    66.0
#
# [57241 rows x 5 columns]

# %%
clean_df[clean_df["Drug/Alcohol Induced Cause Code"].isin(overdoses)]
# Out:
#                      County  County Code    Year  \
# 1        Baldwin County, AL       1003.0  2009.0
# 8        Calhoun County, AL       1015.0  2009.0
# 28      Escambia County, AL       1053.0  2009.0
# 30        Etowah County, AL       1055.0  2009.0
# 38       Houston County, AL       1069.0  2009.0
# ...                     ...          ...     ...
# 4552  Washington County, WI      55131.0  2013.0
# 4555    Waukesha County, WI      55133.0  2013.0
# 4561   Winnebago County, WI      55139.0  2013.0
# 4576     Laramie County, WY      56021.0  2013.0
# 4580     Natrona County, WY      56025.0  2013.0
#
#      Drug/Alcohol Induced Cause Code Deaths
# 1                                 D1   29.0
# 8                                 D1   12.0
# 28                                D4   10.0
# 30                                D1   14.0
# 38                                D1   10.0
# ...                              ...    ...
# 4552                              D1   19.0
# 4555                              D1   39.0
# 4561                              D1   14.0
# 4576                              D1   15.0
# 4580                              D1   14.0
#
# [9804 rows x 5 columns]

# %%
clean_df = clean_df[clean_df["Drug/Alcohol Induced Cause Code"].isin(overdoses)]
clean_df["County Code"] = clean_df["County Code"].astype(int)
clean_df["Year"] = clean_df["Year"].astype(int)
clean_df
# Out:
#                      County  County Code  Year  \
# 1        Baldwin County, AL         1003  2009
# 8        Calhoun County, AL         1015  2009
# 28      Escambia County, AL         1053  2009
# 30        Etowah County, AL         1055  2009
# 38       Houston County, AL         1069  2009
# ...                     ...          ...   ...
# 4552  Washington County, WI        55131  2013
# 4555    Waukesha County, WI        55133  2013
# 4561   Winnebago County, WI        55139  2013
# 4576     Laramie County, WY        56021  2013
# 4580     Natrona County, WY        56025  2013
#
#      Drug/Alcohol Induced Cause Code Deaths
# 1                                 D1   29.0
# 8                                 D1   12.0
# 28                                D4   10.0
# 30                                D1   14.0
# 38                                D1   10.0
# ...                              ...    ...
# 4552                              D1   19.0
# 4555                              D1   39.0
# 4561                              D1   14.0
# 4576                              D1   15.0
# 4580                              D1   14.0
#
#        '41.0', '410.0', '411.0', '42', '42.0', '424.0', '425.0', '43',
#        '43.0', '432.0', '436.0', '439.0', '44', '44.0', '446.0', '45',
#        '45.0', '450.0', '456.0', '459.0', '46', '46.0', '462.0', '468.0',
#        '469.0', '47', '47.0', '472.0', '473.0', '48', '48.0', '485.0',
#        '49', '49.0', '50', '50.0', '51', '51.0', '52', '52.0', '523.0',
#        '525.0', '53', '53.0', '538.0', '539', '54', '54.0', '542.0',
#        '543.0', '545.0', '549', '55', '55.0', '552.0', '56', '56.0',
#        '561.0', '563.0', '566.0', '57', '57.0', '572', '572.0', '58',
#        '58.0', '59', '59.0', '60', '60.0', '61', '61.0', '616.0', '62',
#        '62.0', '621.0', '624', '627.0', '63', '63.0', '636.0', '64',
#        '64.0', '645', '65', '65.0', '66', '66.0', '67', '67.0', '68.0',
#        '683.0', '69.0', '70', '70.0', '705.0', '71', '71.0', '72', '72.0',
#        '73', '73.0', '74', '74.0', '75', '75.0', '76', '76.0', '77.0',
#        '78', '78.0', '79', '79.0', '80', '80.0', '81', '81.0', '82',
#        '82.0', '83', '83.0', '84', '84.0', '85', '85.0', '86', '86.0',
#        '87', '87.0', '88', '88.0', '89', '89.0', '90', '90.0', '91',
#        '91.0', '92.0', '93', '93.0', '94', '94.0', '95', '95.0', '96',
#        '96.0', '97', '97.0', '98', '98.0', '99.0', 'Missing'], dtype='<U7')

# %%
clean_df = clean_df[clean_df["Deaths"] != "Missing"]
clean_df["Deaths"] = clean_df["Deaths"].astype(int)
clean_df.drop(inplace=True, columns="Drug/Alcohol Induced Cause Code")
clean_df
# Out:
#                      County  County Code  Year  Deaths
# 1        Baldwin County, AL         1003  2009      29
# 8        Calhoun County, AL         1015  2009      12
# 28      Escambia County, AL         1053  2009      10
# 30        Etowah County, AL         1055  2009      14
# 38       Houston County, AL         1069  2009      10
# ...                     ...          ...   ...     ...
# 4552  Washington County, WI        55131  2013      19
# 4555    Waukesha County, WI        55133  2013      39
# 4561   Winnebago County, WI        55139  2013      14
# 4576     Laramie County, WY        56021  2013      15
# 4580     Natrona County, WY        56025  2013      14
#
# [9784 rows x 4 columns]

# %%
clean_df.rename(inplace=True, columns={"County Code": "FIPS"})
# Remove Alaska
clean_df = clean_df[clean_df["FIPS"] // 1000 != 2]
clean_df = clean_df.groupby(["FIPS", "County", "Year"], as_index=False).sum()
clean_df
# Out:
#        FIPS                 County  Year  Deaths
# 0      1003     Baldwin County, AL  2003      10
# 1      1003     Baldwin County, AL  2004      18
# 2      1003     Baldwin County, AL  2005      14
# 3      1003     Baldwin County, AL  2006      11
# 4      1003     Baldwin County, AL  2007      24
# ...     ...                    ...   ...     ...
# 7850  56025     Natrona County, WY  2012      12
# 7851  56025     Natrona County, WY  2013      14
# 7852  56025     Natrona County, WY  2014      17
# 7853  56025     Natrona County, WY  2015      13
# 7854  56037  Sweetwater County, WY  2014      13
#
# [7855 rows x 4 columns]

# %%
clean_df.FIPS.nunique()
# Out:
# 1038

# %%
clean_df.to_csv(out_file, index=False, sep="\t")
